# %%
import numpy as np
import tensorflow as tf
import h5py
import os
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import skimage
import cv2
from PIL import Image
from skimage.measure import compare_ssim,compare_psnr

# %%
def show_data(x_in, pre_in):
    mean = np.mean(x_in)
    std = np.std(x_in)
    Max = np.max(x_in)
    Min = np.min(x_in)
    dtype = x_in.dtype
    
    print(pre_in + ' shape: ' + str(x_in.shape) + ' , type: ' + str(dtype) + ' , mean = ' + str(mean) 
          + ' , std = ' + str(std) + ' , Max = ' + str(Max) + ' , Min = ' + str(Min))

# %%
def trans_PNG(data,iname):
    im = Image.fromarray(data)
    im.save(iname,compress_level=0)

# %%
Nx=1024
Ny=1536
NC = 1

NX = 2048
NY = 3072

block_size = 32
stride_size = 32
ncomp = 4

sc_int=73.
Q_scale=1./6.

Trained_model = {}
Trained_model[0] = './model_R/model_200000.ckpt-200001'
Trained_model[1] = './model_G/model_200000.ckpt-200001'
Trained_model[2] = './model_B/model_200000.ckpt-200001'

codes = {}
f_code=h5py.File('./code_32324_1x256_4bit_RcKD.h5','r')
code=f_code['data'][:]
codes[0]=code.astype(np.float32)

f_code=h5py.File('./code_32324_1x256_4bit_GcKD.h5','r')
code=f_code['data'][:]
codes[1]=code.astype(np.float32)

f_code=h5py.File('./code_32324_1x256_4bit_BcKD.h5','r')
code=f_code['data'][:]
codes[2]=code.astype(np.float32)

for i in range(3):
    show_data(codes[i], 'codes_' + str(i))

print('')

scopes = {}
scopes[0] = 'Decomp_NN_32324_fix_code_RB_c0_RcKD'
scopes[1] = 'Decomp_NN_32324_fix_code_RB_c0_GcKD'
scopes[2] = 'Decomp_NN_32324_fix_code_RB_c0_BcKD'
for i in range(3):
    print('scope' + str(i) + ': ' + scopes[i])
# Out:
# codes_0 shape: (32, 32, 1, 4) , type: float32 , mean = -0.3815918 , std = 1.8846478 , Max = 5.0 , Min = -6.0
# codes_1 shape: (32, 32, 1, 4) , type: float32 , mean = 0.020019531 , std = 1.9182739 , Max = 7.0 , Min = -6.0
# codes_2 shape: (32, 32, 1, 4) , type: float32 , mean = 0.22192383 , std = 1.951141 , Max = 5.0 , Min = -5.0
#
# scope0: Decomp_NN_32324_fix_code_RB_c0_RcKD
# scope1: Decomp_NN_32324_fix_code_RB_c0_GcKD
# scope2: Decomp_NN_32324_fix_code_RB_c0_BcKD

# %%
def compression(Data_in, code_in, stride_size, Q_scale, sc_int, Q_type):
    compW = tf.constant(code_in)

    comp = tf.nn.conv2d(Data_in, compW, strides=[1, stride_size, stride_size, 1], padding='VALID')
    print(comp)

    compm = comp*Q_scale
    print(compm)

    compint = tf.cast(compm,Q_type)
    print(compint)

    compf32 = tf.cast(compint,tf.float32)/(sc_int*Q_scale)
    print(compf32)

    return compf32

# %%
def residual_block(input_tense):
    tmp1 = tf.nn.relu(tf.layers.batch_normalization(
        tf.layers.conv2d(input_tense,64,[3,3],[1,1], padding='SAME')))
    tmp2 = tf.nn.relu(tf.layers.batch_normalization(
        tf.layers.conv2d(tmp1,16,[2,2],[1,1], padding='SAME')))
    tmp3 = tf.layers.batch_normalization(
        tf.layers.conv2d(tmp2,1,[1,1],[1,1], padding='SAME'))
    tmp4 = tmp3 + input_tense
    return tmp4

# %%
from xy_inception_tf_model_actv import inception_module,inception_model

def recon_NN(comp_in, NC, block_size, stride_size, scope, reuse=False):
    with tf.variable_scope(scope, reuse=reuse):

        with tf.name_scope('Pre_dcomp'):
            pdcomp = residual_block(comp_in)
            print(pdcomp)

        with tf.name_scope('Dcompress_Conv'):
            dcomp = tf.layers.conv2d_transpose(pdcomp,NC,[block_size,block_size],[stride_size,stride_size], padding='VALID')
            print(dcomp)


        with tf.name_scope('inception_model'):
            outputs=inception_model(dcomp, 8, tf.sigmoid)

        return outputs

# %%
with tf.name_scope('DATA'):
    Data_in = tf.placeholder(tf.float32,shape=[None,Nx,Ny,NC])
    print(Data_in)
# Out:
# Tensor("DATA/Placeholder:0", shape=(?, 1024, 1536, 1), dtype=float32)

# %%
comp_o={}
for i in range(3):
    comp_o[i]=compression(Data_in, codes[i], stride_size, Q_scale, sc_int, tf.int8)
    print(comp_o[i])
    print('')
# Out:
# Tensor("Conv2D:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("mul:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("Cast:0", shape=(?, 32, 48, 4), dtype=int8)
# Tensor("truediv:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("truediv:0", shape=(?, 32, 48, 4), dtype=float32)
#
# Tensor("Conv2D_1:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("mul_1:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("Cast_2:0", shape=(?, 32, 48, 4), dtype=int8)
# Tensor("truediv_1:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("truediv_1:0", shape=(?, 32, 48, 4), dtype=float32)
#
# Tensor("Conv2D_2:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("mul_2:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("Cast_4:0", shape=(?, 32, 48, 4), dtype=int8)
# Tensor("truediv_2:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("truediv_2:0", shape=(?, 32, 48, 4), dtype=float32)

# %%
Recs = {}
for i in range(3):
    Recs[i]=recon_NN(comp_o[i], NC, block_size, stride_size, scopes[i])
    print("\nRecs[" + str(i) + "]: " + str(Recs[i]))
    print('\n')
# Out:
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/Pre_dcomp/add:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/Dcompress_Conv/conv2d_transpose/BiasAdd:0", shape=(?, 1024, 1536, 1), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_0/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_0/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_0/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_0/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_0/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_0/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_1/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_1/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_1/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_1/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_1/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_1/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_2/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_2/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_2/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_2/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_2/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_2/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_3/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_3/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_3/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_3/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_3/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_3/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_4/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_4/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_4/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_4/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_4/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_4/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_5/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_5/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_5/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_5/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_5/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_5/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_6/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_6/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_6/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_6/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_6/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_6/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_7/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_7/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_7/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_7/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_7/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/inception_modules_7/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/LeakyRelu_1/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/concat_1:0", shape=(?, 1024, 1536, 192), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
#
# Recs[0]: Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/Pre_dcomp/add:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/Dcompress_Conv/conv2d_transpose/BiasAdd:0", shape=(?, 1024, 1536, 1), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_0/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_0/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_0/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_0/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_0/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_0/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_1/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_1/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_1/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_1/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_1/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_1/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_2/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_2/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_2/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_2/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_2/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_2/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_3/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_3/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_3/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_3/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_3/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_3/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_4/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_4/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_4/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_4/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_4/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_4/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_5/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_5/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_5/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_5/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_5/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_5/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_6/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_6/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_6/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_6/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_6/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_6/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_7/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_7/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_7/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_7/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_7/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/inception_modules_7/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/LeakyRelu_1/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/concat_1:0", shape=(?, 1024, 1536, 192), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
#
# Recs[1]: Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/Pre_dcomp/add:0", shape=(?, 32, 48, 4), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/Dcompress_Conv/conv2d_transpose/BiasAdd:0", shape=(?, 1024, 1536, 1), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_0/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_0/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_0/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_0/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_0/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_0/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_1/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_1/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_1/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_1/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_1/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_1/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_2/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_2/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_2/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_2/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_2/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_2/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_3/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_3/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_3/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_3/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_3/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_3/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_4/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_4/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_4/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_4/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_4/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_4/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_5/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_5/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_5/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_5/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_5/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_5/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_6/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_6/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_6/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_6/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_6/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_6/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_7/conv2d/BiasAdd:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_7/batch_normalization/FusedBatchNorm:0", shape=(?, 1024, 1536, 64), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_7/conv2d_1/BiasAdd:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_7/batch_normalization_1/FusedBatchNorm:0", shape=(?, 1024, 1536, 32), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_7/Add:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/inception_modules_7/LeakyRelu/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/LeakyRelu_1/Maximum:0", shape=(?, 1024, 1536, 96), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/concat_1:0", shape=(?, 1024, 1536, 192), dtype=float32)
# Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
#
# Recs[2]: Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)

# %%
var_s = {}
for i in range(3):
    var_s[i] = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=scopes[i])
    print('var_s_' + str(i) + ':\n')
    print(var_s[i])
    print('\n')
# Out:
# var_s_0:
#
# [<tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d/kernel:0' shape=(3, 3, 4, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_1/kernel:0' shape=(2, 2, 64, 16) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_1/bias:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_1/gamma:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_1/beta:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_2/kernel:0' shape=(1, 1, 16, 1) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_2/bias:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_2/gamma:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_2/beta:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_transpose/kernel:0' shape=(32, 32, 1, 4) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_transpose/bias:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_3/kernel:0' shape=(3, 3, 1, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_3/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_3/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_3/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_4/kernel:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_4/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_4/gamma:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_4/beta:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_5/kernel:0' shape=(3, 3, 96, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_5/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_5/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_5/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_6/kernel:0' shape=(5, 5, 96, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_6/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_6/gamma:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_6/beta:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_7/kernel:0' shape=(3, 3, 96, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_7/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_7/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_7/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_8/kernel:0' shape=(5, 5, 96, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/conv2d_8/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_RcKD/batch_normalization_8/gamma:0' shape=(32,) dtype=float32_re ...
#
#
# var_s_1:
#
# [<tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d/kernel:0' shape=(3, 3, 4, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_1/kernel:0' shape=(2, 2, 64, 16) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_1/bias:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_1/gamma:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_1/beta:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_2/kernel:0' shape=(1, 1, 16, 1) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_2/bias:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_2/gamma:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_2/beta:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_transpose/kernel:0' shape=(32, 32, 1, 4) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_transpose/bias:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_3/kernel:0' shape=(3, 3, 1, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_3/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_3/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_3/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_4/kernel:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_4/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_4/gamma:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_4/beta:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_5/kernel:0' shape=(3, 3, 96, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_5/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_5/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_5/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_6/kernel:0' shape=(5, 5, 96, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_6/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_6/gamma:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_6/beta:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_7/kernel:0' shape=(3, 3, 96, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_7/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_7/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_7/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_8/kernel:0' shape=(5, 5, 96, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/conv2d_8/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_GcKD/batch_normalization_8/gamma:0' shape=(32,) dtype=float32_re ...
#
#
# var_s_2:
#
# [<tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d/kernel:0' shape=(3, 3, 4, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_1/kernel:0' shape=(2, 2, 64, 16) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_1/bias:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_1/gamma:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_1/beta:0' shape=(16,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_2/kernel:0' shape=(1, 1, 16, 1) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_2/bias:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_2/gamma:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_2/beta:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_transpose/kernel:0' shape=(32, 32, 1, 4) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_transpose/bias:0' shape=(1,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_3/kernel:0' shape=(3, 3, 1, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_3/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_3/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_3/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_4/kernel:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_4/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_4/gamma:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_4/beta:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_5/kernel:0' shape=(3, 3, 96, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_5/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_5/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_5/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_6/kernel:0' shape=(5, 5, 96, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_6/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_6/gamma:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_6/beta:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_7/kernel:0' shape=(3, 3, 96, 64) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_7/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_7/gamma:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_7/beta:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_8/kernel:0' shape=(5, 5, 96, 32) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/conv2d_8/bias:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Decomp_NN_32324_fix_code_RB_c0_BcKD/batch_normalization_8/gamma:0' shape=(32,) dtype=float32_re ...

# %%
savers = {}
for i in range(3):
    savers[i] = tf.train.Saver(var_list=var_s[i])
    print('savers_' + str(i) + ':')
    print(str(savers[i]))
    print('\n')
# Out:
# savers_0:
# <tensorflow.python.training.saver.Saver object at 0x7f934180a588>
#
#
# savers_1:
# <tensorflow.python.training.saver.Saver object at 0x7f93408e2e80>
#
#
# savers_2:
# <tensorflow.python.training.saver.Saver object at 0x7f93400c8dd8>

# %%
init = tf.global_variables_initializer()

# %%
def run_recon(data_in, Rec_in, trained_model, saver_in):
    with tf.Session() as sess:
        sess.run(init)
        saver_in.restore(sess,trained_model)
        dip=sess.run(Rec_in,feed_dict={Data_in:data_in})
            
    return dip

# %%
xs_s={}; ys_s={};

xs_s[0]=0; ys_s[0]=0
xs_s[1]=Nx; ys_s[1]=0
xs_s[2]=0; ys_s[2]=Ny
xs_s[3]=Nx; ys_s[3]=Ny

for i in range(4):
    print(str(i) + " xs= " + str(xs_s[i]) + " , ys= " + str(ys_s[i]))
# Out:
# 0 xs= 0 , ys= 0
# 1 xs= 1024 , ys= 0
# 2 xs= 0 , ys= 1536
# 3 xs= 1024 , ys= 1536

# %%
def big_frame_recon(data_in, Rec_in, trained_model, saver_in):
    print('big_frame_recon, Rec_in: ' + str(Rec_in))
    Dips={}
    for i in range(4):
        xs=xs_s[i]; xe=xs+Nx
        ys=ys_s[i]; ye=ys+Ny
        data_f=np.zeros([1,Nx,Ny,NC])
        data_f[0,:,:,0]=data_in[xs:xe,ys:ye]
        Dips[i]=run_recon(data_f, Rec_in, trained_model, saver_in)
        
    shape_o=[NX,NY]
    Dip=np.zeros(shape_o)
    for i in range(4):
        xs=xs_s[i]; xe=xs+Nx
        ys=ys_s[i]; ye=ys+Ny
        Dip[xs:xe,ys:ye]=Dips[i][0,:,:,0]
        
    return Dip

# %%
def kd_fname(i_in):
    rname = '/IMG000' + str(i_in) + '.dib'
    if i_in >9: rname = '/IMG00' + str(i_in) + '.dib'
        
    return rname

# %%
pref = '../Kodak_examples_uncompressed'

# %%
Ns_t = 1
Ne_t = 4
Nf_t = 3

# %%
Data_t = np.zeros([Nf_t,2048,3072,3])
recon_t = np.zeros([Nf_t,2048,3072,3])
i_n=0
for i in range(Ns_t, Ne_t):
    fname = pref + kd_fname(i)
    print(fname)
    tim = cv2.imread(fname)
    
    for inc in range(3):
        print('channel' + str(inc))
        timt = tim[...,inc]
    
        npix = timt.shape[0]*timt.shape[1]
        assert(npix == 2048*3072)
        if timt.shape[0]!=2048: timt = np.rot90(timt,k=1)
    
        show_data(timt, '  image')
    
        Data_t[i_n,:,:,inc] = timt.astype(np.float)/255.0
        show_data(Data_t[i_n,:,:,inc], '  Data_t')
    
        recon_t[i_n,:,:,inc] = big_frame_recon(Data_t[i_n,:,:,inc], Recs[inc], Trained_model[inc], savers[inc])
        show_data(recon_t[i_n,:,:,inc], '  recon_t')
    
        mse=np.mean(np.square(Data_t[i_n,:,:,inc]-recon_t[i_n,:,:,inc]))
        print("  mse = " + str(mse) + '\n')
    
    print("\n")
    
    i_n = i_n+1
# Out:
# ../Kodak_examples_uncompressed/IMG0001.dib
# channel0
#   image shape: (2048, 3072) , type: uint8 , mean = 87.41269111633301 , std = 48.138943111710766 , Max = 249 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.3427948671228745 , std = 0.18878016906553044 , Max = 0.9764705882352941 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.34269845870315335 , std = 0.18582421968889756 , Max = 0.923552930355072 , Min = 0.0011901927646249533
#   mse = 0.001130250320071879
#
# channel1
#   image shape: (2048, 3072) , type: uint8 , mean = 83.42011435826619 , std = 57.99546794301129 , Max = 255 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.3271377033657497 , std = 0.2274332076196523 , Max = 1.0 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.3273630795133384 , std = 0.2231860827116502 , Max = 0.9819493889808655 , Min = 0.0006989507237449288
#   mse = 0.0021140563334829704
#
# channel2
#   image shape: (2048, 3072) , type: uint8 , mean = 147.8918924331665 , std = 30.826136266835753 , Max = 255 , Min = 2
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.5799682056202604 , std = 0.1208868088895506 , Max = 1.0 , Min = 0.00784313725490196
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.5798632765706735 , std = 0.1164088930002621 , Max = 0.8767045140266418 , Min = 0.00998978316783905
#   mse = 0.000970251913715135
#
#
#
# ../Kodak_examples_uncompressed/IMG0002.dib
# channel0
#   image shape: (2048, 3072) , type: uint8 , mean = 99.11118666330974 , std = 47.607980435489026 , Max = 255 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.3886713202482732 , std = 0.18669796249211348 , Max = 1.0 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.38870949110015535 , std = 0.18096482338213446 , Max = 0.9342832565307617 , Min = 0.04812411963939667
#   mse = 0.0019639507833784427
#
# channel1
#   image shape: (2048, 3072) , type: uint8 , mean = 123.38589604695638 , std = 40.964871971652826 , Max = 255 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.4838662590076714 , std = 0.1606465567515798 , Max = 1.0 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.48396848979762613 , std = 0.15455579632321118 , Max = 0.9755633473396301 , Min = 0.052812039852142334
#   mse = 0.0019497641218707569
#
# channel2
#   image shape: (2048, 3072) , type: uint8 , mean = 134.9800125757853 , std = 41.583112737586674 , Max = 255 , Min = 8
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.529333382650138 , std = 0.16307103034347714 , Max = 1.0 , Min = 0.03137254901960784
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.5293846411876757 , std = 0.1580441941403346 , Max = 0.99895179271698 , Min = 0.07918839901685715
#   mse = 0.0015562865350525247
#
#
#
# ../Kodak_examples_uncompressed/IMG0003.dib
# channel0
#   image shape: (2048, 3072) , type: uint8 , mean = 83.45024108886719 , std = 51.480218564491715 , Max = 243 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.32725584740732244 , std = 0.2018832100568302 , Max = 0.9529411764705882 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_RcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_R/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.32720687868392195 , std = 0.1999167634394144 , Max = 0.9332984685897827 , Min = 0.0009540396858938038
#   mse = 0.0008225598731561359
#
# channel1
#   image shape: (2048, 3072) , type: uint8 , mean = 114.91007248560588 , std = 53.87229167721776 , Max = 254 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.45062773523766997 , std = 0.21126388893026576 , Max = 0.996078431372549 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_GcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_G/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.45079882553174117 , std = 0.20935496393222958 , Max = 0.980878472328186 , Min = 0.000666196399834007
#   mse = 0.0009376038943594583
#
# channel2
#   image shape: (2048, 3072) , type: uint8 , mean = 127.75852584838867 , std = 52.28869570820767 , Max = 255 , Min = 0
#   Data_t shape: (2048, 3072) , type: float64 , mean = 0.5010138268564255 , std = 0.20505370865963637 , Max = 1.0 , Min = 0.0
# big_frame_recon, Rec_in: Tensor("Decomp_NN_32324_fix_code_RB_c0_BcKD/inception_model/conv2d_3/Sigmoid:0", shape=(?, 1024, 1536, 1), dtype=float32)
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
# INFO:tensorflow:Restoring parameters from ./model_B/model_200000.ckpt-200001
#   recon_t shape: (2048, 3072) , type: float64 , mean = 0.5009332146295323 , std = 0.20350813716760657 , Max = 0.9743131399154663 , Min = 0.06400925666093826
#   mse = 0.0005458816285629168

# %%
pre_r_s = './KD_32324/'
for i in range(Nf_t): #Nf_t
    print(i)
    
    label = np.zeros([Data_t.shape[1], Data_t.shape[2],3])
    recon = np.zeros([Data_t.shape[1], Data_t.shape[2],3])
    label[...,0] = Data_t[i,:,:,2]; recon[...,0] = recon_t[i,:,:,2]
    label[...,1] = Data_t[i,:,:,1]; recon[...,1] = recon_t[i,:,:,1]
    label[...,2] = Data_t[i,:,:,0]; recon[...,2] = recon_t[i,:,:,0]
    label = (label*255).astype('uint8')
    recon = (recon*255).astype('uint8')
    
    psnr =compare_psnr(recon, label)
    ssim =compare_ssim(recon, label, multichannel=True)
    print("  psnr= " + str(psnr) + " , ssim= " + str(ssim))
    
    plt.figure(figsize=(16, 18))

    plt.subplot(1,2,1)
    plt.imshow(label)
    
    plt.subplot(1,2,2)    
    plt.imshow(recon)
    plt.title('psnr=' + str(psnr) + " , ssim=" +str(ssim))
    plt.show()
    
    idx = i+1
    #oname = pre_o_s + str(idx) + '.png'
    rname = pre_r_s + str(idx) + '.png'
    #trans_PNG(label,oname)
    trans_PNG(recon,rname)
# Out:
# 0
#   psnr= 28.507975443514088 , ssim= 0.7521983951184925
# 1
#   psnr= 27.379795062245208 , ssim= 0.6893565442488553
# 2
#   psnr= 31.1138376276371 , ssim= 0.8580387905855908
